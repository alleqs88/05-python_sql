# %% [markdown]
# # ETL simples com SQLAlchemy Core + Pandas
# ## Simulando Bronze → Silver → Gold
#
# Neste notebook vamos construir um ETL didático usando **SQLAlchemy Core**, **Pandas** e **PostgreSQL**.
#
# ### Fluxo
#
# ```text
# PostgreSQL
#     │
#     │ SQL
#     ▼
#   BRONZE
#     │
#     │ Pandas
#     │ limpeza + cálculos
#     ▼
#   SILVER
#     │
#     │ SQL
#     │ agregações
#     ▼
#    GOLD
#     │
#     ▼
#  Power BI / BI
# ```
#
# > Objetivo: entender ETL e camadas de dados.

# %% [markdown]
# ## 1. Instalação
#
# Se necessário:
#
# ```bash
# pip install pandas sqlalchemy psycopg2-binary
# ```

# %%
import pandas as pd
from sqlalchemy import create_engine, text

print("Bibliotecas carregadas!")
# Out:
# Bibliotecas carregadas!

# %% [markdown]
# ## 2. Conexão com PostgreSQL
#
# Estamos usando **SQLAlchemy Core**, sem ORM.

# %%
# Ajuste os dados conforme seu ambiente

engine = create_engine(
    "postgresql+psycopg2://postgres:postgres@localhost:5432/loja_brasil"
)

print("Engine criada!")
# Out:
# Engine criada!

# %% [markdown]
# ## 3. Criar o schema do ETL
#
# Vamos utilizar o schema `etl` para armazenar as camadas.

# %%
with engine.begin() as conn:
    conn.execute(text("CREATE SCHEMA IF NOT EXISTS etl"))

print("Schema etl criado!")
# Out:
# Schema etl criado!

# %% [markdown]
# # 🥉 BRONZE
#
# A Bronze representa os dados **brutos**, próximos da origem.
#
# Vamos extrair dados de `vendas.pedidos` e `vendas.itens_pedido` usando **SQL**.

# %% [markdown]
# ## 4. EXTRACT — SQL
#
# ```sql
# SELECT
#     p.id_pedido,
#     p.data_pedido,
#     p.id_cliente,
#     i.id_produto,
#     i.quantidade,
#     i.preco_unitario,
#     i.desconto
# FROM vendas.pedidos p
# INNER JOIN vendas.itens_pedido i
#     ON p.id_pedido = i.id_pedido;
# ```

# %% [markdown]
# ## Exercício 1: Adicionar status na consulta.

# %%
# Adicionando p.status na consulta
sql_bronze = text(
    '''
    SELECT
        p.id_pedido,
        p.data_pedido,
        p.id_cliente,
        i.id_produto,
        i.quantidade,
        i.preco_unitario,
        i.desconto,
        p.status 
    FROM vendas.pedidos p
    INNER JOIN vendas.itens_pedido i
        ON p.id_pedido = i.id_pedido;
    '''
)

print(sql_bronze)
# Out:
#     SELECT
#         p.id_pedido,
#         p.data_pedido,
#         p.id_cliente,
#         i.id_produto,
#         i.quantidade,
#         i.preco_unitario,
#         i.desconto,
#         p.status
#     FROM vendas.pedidos p
#     INNER JOIN vendas.itens_pedido i
#         ON p.id_pedido = i.id_pedido;

# %% [markdown]
# ## 5. Executar o SQL e carregar no Pandas
#
# `pd.read_sql()` recebe o comando SQL e uma conexão SQLAlchemy.

# %%
with engine.connect() as conn:
    df_bronze = pd.read_sql(sql_bronze, conn)

df_bronze.head()
# Out:
#    id_pedido data_pedido  id_cliente  id_produto  quantidade  preco_unitario  \
# 0          1  2025-02-10           8           6           2           159.9
# 1          1  2025-02-10           8          13           3            79.9
# 2          1  2025-02-10           8           2           4            89.9
# 3          2  2025-02-19          15          11           3           199.9
# 4          2  2025-02-19          15          18           4            54.9
#
#    desconto    status
# 0       0.0  Pendente
# 1       5.0  Pendente
# 2      10.0  Pendente
# 3       5.0  Entregue
# 4      10.0  Entregue

# %%
print("Linhas:", len(df_bronze))
print("Colunas:", df_bronze.columns.tolist())
# Out:
# Linhas: 180
# Colunas: ['id_pedido', 'data_pedido', 'id_cliente', 'id_produto', 'quantidade', 'preco_unitario', 'desconto', 'status']

# %% [markdown]
# ## 6. Salvar a Bronze
#
# Usaremos `to_sql()` para carregar o DataFrame no PostgreSQL.

# %%
df_bronze.to_sql(
    "vendas_bronze",
    con=engine,
    schema="etl",
    if_exists="replace",
    index=False
)

print("Bronze carregada!")
# Out:
# Bronze carregada!

# %% [markdown]
# ## 7. Consultar a Bronze com SQL

# %%
sql = text(
    '''
    SELECT *
    FROM etl.vendas_bronze
    LIMIT 10;
    '''
)

with engine.connect() as conn:
    df_teste_bronze = pd.read_sql(sql, conn)

df_teste_bronze
# Out:
#    id_pedido data_pedido  id_cliente  id_produto  quantidade  preco_unitario  \
# 0          1  2025-02-10           8           6           2           159.9
# 1          1  2025-02-10           8          13           3            79.9
# 2          1  2025-02-10           8           2           4            89.9
# 3          2  2025-02-19          15          11           3           199.9
# 4          2  2025-02-19          15          18           4            54.9
# 5          2  2025-02-19          15           7           1           189.9
# 6          2  2025-02-19          15          14           2           169.9
# 7          3  2025-02-28           2          16           4            69.9
# 8          3  2025-02-28           2           5           1           139.9
# 9          4  2025-03-09           9           3           1            69.9
#
#    desconto     status
# 0       0.0   Pendente
# 1       5.0   Pendente
# 2      10.0   Pendente
# 3       5.0   Entregue
# 4      10.0   Entregue
# 5       0.0   Entregue
# 6       0.0   Entregue
# 7      10.0    Enviado
# 8       0.0    Enviado
# 9       0.0  Cancelado

# %% [markdown]
# # 🥈 SILVER
#
# A Silver contém dados **limpos e tratados**.
#
# Vamos usar Pandas para:
#
# 1. remover valores ausentes;
# 2. calcular valor bruto;
# 3. calcular desconto;
# 4. calcular valor líquido.

# %%
df_silver = df_bronze.copy()

df_silver.head()
# Out:
#    id_pedido data_pedido  id_cliente  id_produto  quantidade  preco_unitario  \
# 0          1  2025-02-10           8           6           2           159.9
# 1          1  2025-02-10           8          13           3            79.9
# 2          1  2025-02-10           8           2           4            89.9
# 3          2  2025-02-19          15          11           3           199.9
# 4          2  2025-02-19          15          18           4            54.9
#
#    desconto    status
# 0       0.0  Pendente
# 1       5.0  Pendente
# 2      10.0  Pendente
# 3       5.0  Entregue
# 4      10.0  Entregue

# %% [markdown]
# ## 8. Limpeza dos dados

# %%
print("Antes:", len(df_silver))

df_silver = df_silver.dropna()

print("Depois:", len(df_silver))
# Out:
# Antes: 180
# Depois: 180

# %% [markdown]
# ## 9. Valor bruto
#
# ```text
# valor_bruto = quantidade × preco_unitario
# ```

# %%
df_silver["valor_bruto"] = (
    df_silver["quantidade"] *
    df_silver["preco_unitario"]
)

df_silver[
    ["quantidade", "preco_unitario", "valor_bruto"]
].head(10)
# Out:
#    quantidade  preco_unitario  valor_bruto
# 0           2           159.9        319.8
# 1           3            79.9        239.7
# 2           4            89.9        359.6
# 3           3           199.9        599.7
# 4           4            54.9        219.6
# 5           1           189.9        189.9
# 6           2           169.9        339.8
# 7           4            69.9        279.6
# 8           1           139.9        139.9
# 9           1            69.9         69.9

# %% [markdown]
# ## 10. Valor do desconto
#
# ```text
# valor_desconto = valor_bruto × desconto / 100
# ```

# %%
df_silver["valor_desconto"] = (
    df_silver["valor_bruto"] *
    df_silver["desconto"] / 100
)

df_silver[
    ["valor_bruto", "desconto", "valor_desconto"]
].head()
# Out:
#    valor_bruto  desconto  valor_desconto
# 0        319.8       0.0           0.000
# 1        239.7       5.0          11.985
# 2        359.6      10.0          35.960
# 3        599.7       5.0          29.985
# 4        219.6      10.0          21.960

# %% [markdown]
# ## 11. Valor líquido
#
# ```text
# valor_liquido = valor_bruto - valor_desconto
# ```

# %%
df_silver["valor_liquido"] = (
    df_silver["valor_bruto"] -
    df_silver["valor_desconto"]
)

df_silver[
    ["valor_bruto", "valor_desconto", "valor_liquido"]
].head()
# Out:
#    valor_bruto  valor_desconto  valor_liquido
# 0        319.8           0.000        319.800
# 1        239.7          11.985        227.715
# 2        359.6          35.960        323.640
# 3        599.7          29.985        569.715
# 4        219.6          21.960        197.640

# %% [markdown]
# ## Exercício 2: Criando coluna ticket_medio_item.

# %%
# Criando a coluna ticket_medio_item
df_silver["ticket_medio_item"] = (
    df_silver["valor_liquido"] /
    df_silver["quantidade"]
)

df_silver[
    ['valor_liquido', 'quantidade', 'ticket_medio_item']
].head()
# Out:
#    valor_liquido  quantidade  ticket_medio_item
# 0        319.800           2            159.900
# 1        227.715           3             75.905
# 2        323.640           4             80.910
# 3        569.715           3            189.905
# 4        197.640           4             49.410

# %% [markdown]
# ## 12. Visualizar a Silver

# %%
df_silver.head()
# Out:
#    id_pedido data_pedido  id_cliente  id_produto  quantidade  preco_unitario  \
# 0          1  2025-02-10           8           6           2           159.9
# 1          1  2025-02-10           8          13           3            79.9
# 2          1  2025-02-10           8           2           4            89.9
# 3          2  2025-02-19          15          11           3           199.9
# 4          2  2025-02-19          15          18           4            54.9
#
#    desconto    status  valor_bruto  valor_desconto  valor_liquido  \
# 0       0.0  Pendente        319.8           0.000        319.800
# 1       5.0  Pendente        239.7          11.985        227.715
# 2      10.0  Pendente        359.6          35.960        323.640
# 3       5.0  Entregue        599.7          29.985        569.715
# 4      10.0  Entregue        219.6          21.960        197.640
#
#    ticket_medio_item
# 0            159.900
# 1             75.905
# 2             80.910
# 3            189.905
# 4             49.410

# %% [markdown]
# ## Exercício 3: Usando um filtro que mostre os registros com quantidade > 1.

# %%
df_silver[df_silver["quantidade"] > 1].head(20)
# Out:
#     id_pedido data_pedido  id_cliente  id_produto  quantidade  preco_unitario  \
# 0           1  2025-02-10           8           6           2           159.9
# 1           1  2025-02-10           8          13           3            79.9
# 2           1  2025-02-10           8           2           4            89.9
# 3           2  2025-02-19          15          11           3           199.9
# 4           2  2025-02-19          15          18           4            54.9
# 6           2  2025-02-19          15          14           2           169.9
# 7           3  2025-02-28           2          16           4            69.9
# 10          4  2025-03-09           9          10           2           249.9
# 11          4  2025-03-09           9          17           3            29.9
# 12          5  2025-03-18          16           8           2           129.9
# 13          5  2025-03-18          16          15           3            49.9
# 14          5  2025-03-18          16           4           4           149.9
# 16          6  2025-03-27           3          13           3            79.9
# 17          6  2025-03-27           3           2           4            89.9
# 18          7  2025-04-05          10          18           4            54.9
# 20          7  2025-04-05          10          14           2           169.9
# 22          8  2025-04-14          17          12           2           279.9
# 23          8  2025-04-14          17           1           3            59.9
# 24          8  2025-04-14          17           8           4           129.9
# 25          9  2025-04-23           4          10           2           249.9
#
#     desconto     status  valor_bruto  valor_desconto  valor_liquido  \
# 0        0.0   Pendente        319.8           0.000        319.800
# 1        5.0   Pendente        239.7          11.985        227.715
# 2       10.0   Pendente        359.6          35.960        323.640
# 3        5.0   Entregue        599.7          29.985        569.715
# 4       10.0   Entregue        219.6          21.960        197.640
# 6        0.0   Entregue        339.8           0.000        339.800
# 7       10.0    Enviado        279.6          27.960        251.640
# 10       0.0  Cancelado        499.8           0.000        499.800
# 11       5.0  Cancelado         89.7           4.485         85.215
# 12       0.0   Entregue        259.8           0.000        259.800
# 13       5.0   Entregue        149.7           7.485        142.215
# 14      10.0   Entregue        599.6          59.960        539.640
# 16       5.0   Entregue        239.7          11.985        227.715
# 17      10.0   Entregue        359.6          35.960        323.640
# 18      10.0       Pago        219.6          21.960        197.640
# 20       0.0       Pago        339.8           0.000        339.800
# 22       0.0   Pendente        559.8           0.000        559.800
# 23       5.0   Pendente        179.7           8.985        170.715
# 24      10.0   Pendente        519.6          51.960        467.640
# 25       0.0   Entregue        499.8           0.000        499.800
#
#     ticket_medio_item
# 0             159.900
# 1              75.905
# 2              80.910
# 3             189.905
# 4              49.410
# 6             169.900
# 7              62.910
# 10            249.900
# 11             28.405
# 12            129.900
# 13             47.405
# 14            134.910
# 16             75.905
# 17             80.910
# 18             49.410
# 20            169.900
# 22            279.900
# 23             56.905
# 24            116.910
# 25            249.900

# %% [markdown]
# ## 13. Carregar a Silver no PostgreSQL
#
# Destino:
#
# ```text
# etl.vendas_silver
# ```

# %%
df_silver.to_sql(
    "vendas_silver",
    con=engine,
    schema="etl",
    if_exists="replace",
    index=False
)

print("Silver carregada!")
# Out:
# Silver carregada!

# %% [markdown]
# # 🥇 GOLD
#
# A Gold contém dados **prontos para consumo**.
#
# Neste exemplo:
#
# > Faturamento total e quantidade vendida por produto.

# %% [markdown]
# ## 14. SQL explícito para criar a Gold
#
# ```sql
# SELECT
#     id_produto,
#     SUM(quantidade) AS quantidade_vendida,
#     SUM(valor_liquido) AS faturamento
# FROM etl.vendas_silver
# GROUP BY id_produto
# ORDER BY faturamento DESC;
# ```

# %%
sql_gold = text(
    '''
    SELECT
        id_produto,
        SUM(quantidade) AS quantidade_vendida,
        SUM(valor_liquido) AS faturamento
    FROM etl.vendas_silver
    GROUP BY id_produto
    ORDER BY faturamento DESC;
    '''
)

# %% [markdown]
# ## 15. Executar a consulta Gold e carregar no Pandas

# %%
with engine.connect() as conn:
    df_gold = pd.read_sql(sql_gold, conn)

df_gold.head(10)
# Out:
#    id_produto  quantidade_vendida  faturamento
# 0          10                30.0     6997.200
# 1          14                36.0     5776.600
# 2           8                42.0     5040.120
# 3          11                26.0     5017.490
# 4           4                32.0     4437.040
# 5          12                16.0     4254.480
# 6           5                27.0     3630.405
# 7           2                42.0     3524.080
# 8           7                18.0     3304.260
# 9           6                22.0     3261.960

# %% [markdown]
# ## 16. Carregar a Gold no PostgreSQL

# %%
df_gold.to_sql(
    "vendas_gold",
    con=engine,
    schema="etl",
    if_exists="replace",
    index=False
)

print("Gold carregada!")
# Out:
# Gold carregada!

# %% [markdown]
# ## 17. Consultar a Gold

# %%
sql = text(
    '''
    SELECT *
    FROM etl.vendas_gold
    ORDER BY faturamento DESC
    LIMIT 10;
    '''
)

with engine.connect() as conn:
    resultado = pd.read_sql(sql, conn)

resultado
# Out:
#    id_produto  quantidade_vendida  faturamento
# 0          10                30.0     6997.200
# 1          14                36.0     5776.600
# 2           8                42.0     5040.120
# 3          11                26.0     5017.490
# 4           4                32.0     4437.040
# 5          12                16.0     4254.480
# 6           5                27.0     3630.405
# 7           2                42.0     3524.080
# 8           7                18.0     3304.260
# 9           6                22.0     3261.960

# %% [markdown]
# # 18. Validando as três camadas
#
# Podemos verificar a quantidade de registros em cada camada.

# %%
sql = text(
    '''
    SELECT
        (SELECT COUNT(*) FROM etl.vendas_bronze) AS bronze,
        (SELECT COUNT(*) FROM etl.vendas_silver) AS silver,
        (SELECT COUNT(*) FROM etl.vendas_gold) AS gold;
    '''
)

with engine.connect() as conn:
    df_contagem = pd.read_sql(sql, conn)

df_contagem
# Out:
#    bronze  silver  gold
# 0     180     180    18

# %% [markdown]
# # 19. Outra Gold — faturamento por cliente
#
# Uma mesma Silver pode alimentar várias tabelas Gold.

# %%
sql_gold_cliente = text(
    '''
    SELECT
        id_cliente,
        COUNT(DISTINCT id_pedido) AS quantidade_pedidos,
        SUM(valor_liquido) AS faturamento
    FROM etl.vendas_silver
    GROUP BY id_cliente
    ORDER BY faturamento DESC;
    '''
)

with engine.connect() as conn:
    df_gold_cliente = pd.read_sql(sql_gold_cliente, conn)

df_gold_cliente.head(10)
# Out:
#    id_cliente  quantidade_pedidos  faturamento
# 0          12                   3     3536.225
# 1           3                   3     3159.165
# 2          18                   3     3148.935
# 3           7                   3     3064.165
# 4          16                   3     2989.225
# 5           4                   3     2981.225
# 6          15                   3     2977.165
# 7          11                   3     2955.165
# 8          20                   3     2878.225
# 9           6                   3     2841.435

# %%
df_gold_cliente.to_sql(
    "faturamento_cliente_gold",
    con=engine,
    schema="etl",
    if_exists="replace",
    index=False
)

print("Gold de clientes carregada!")
# Out:
# Gold de clientes carregada!

# %% [markdown]
# ## Exercício 4: Criando uma gold com: id_cliente, faturamento

# %%
sql_gold_cliente4 = text(
     '''
        SELECT
            id_cliente,
            SUM(valor_liquido) AS faturamento
        FROM etl.vendas_silver
        GROUP BY id_cliente
        ORDER BY faturamento DESC;
        '''
)

with engine.connect() as conn:
    df_gold_cliente4 = pd.read_sql(sql_gold_cliente4, conn)

df_gold_cliente4.head(10)
# Out:
#    id_cliente  faturamento
# 0          12     3536.225
# 1           3     3159.165
# 2          18     3148.935
# 3           7     3064.165
# 4          16     2989.225
# 5           4     2981.225
# 6          15     2977.165
# 7          11     2955.165
# 8          20     2878.225
# 9           6     2841.435

# %% [markdown]
# ## Exercício 5: criando uma gold com: id_produto, quantidade_vendida, faturamento

# %%
sql_gold_analitico = text(
     '''
        SELECT
            id_produto,
            sum(quantidade) As quantidade_vendida,
            SUM(valor_liquido) AS faturamento
        FROM etl.vendas_silver
        GROUP BY id_produto
        ORDER BY faturamento DESC;
        '''
)

with engine.connect() as conn:
    df_gold_analitico = pd.read_sql(sql_gold_analitico, conn)

df_gold_analitico.head(10)
# Out:
#    id_produto  quantidade_vendida  faturamento
# 0          10                30.0     6997.200
# 1          14                36.0     5776.600
# 2           8                42.0     5040.120
# 3          11                26.0     5017.490
# 4           4                32.0     4437.040
# 5          12                16.0     4254.480
# 6           5                27.0     3630.405
# 7           2                42.0     3524.080
# 8           7                18.0     3304.260
# 9           6                22.0     3261.960

# %% [markdown]
# ## Desafio Final: Criando uma gold faturamento mensal.

# %%
sql_gold_faturamento_mensal = text(
     '''
        SELECT
            DATE_TRUNC('month', data_pedido) As mes,
            SUM(valor_liquido) AS faturamento
        FROM etl.vendas_silver
        GROUP BY mes
        ORDER BY mes;
       
     '''
)

with engine.connect() as conn:
    df_gold_faturamento_mensal = pd.read_sql(sql_gold_faturamento_mensal, conn)

df_gold_faturamento_mensal.head(10)
# Out:
#                         mes  faturamento
# 0 2025-02-01 03:00:00+00:00     5119.500
# 1 2025-03-01 03:00:00+00:00     5422.990
# 2 2025-04-01 03:00:00+00:00     5455.235
# 3 2025-05-01 03:00:00+00:00     6501.575
# 4 2025-06-01 03:00:00+00:00     6305.575
# 5 2025-07-01 03:00:00+00:00     7341.055
# 6 2025-08-01 03:00:00+00:00     6368.350
# 7 2025-09-01 03:00:00+00:00     3248.410
# 8 2025-10-01 03:00:00+00:00     4199.865
# 9 2025-11-01 03:00:00+00:00     3097.910

# %% [markdown]
# # 20. Fluxo completo
#
# ```text
#                   POSTGRESQL
#                        │
#                        │ SELECT
#                        ▼
#               ┌─────────────────┐
#               │     BRONZE      │
#               │ vendas_bronze   │
#               └────────┬────────┘
#                        │
#                        │ Pandas
#                        │ limpeza
#                        │ cálculos
#                        ▼
#               ┌─────────────────┐
#               │     SILVER      │
#               │ vendas_silver   │
#               └────────┬────────┘
#                        │
#                        │ SQL
#                        │ GROUP BY / SUM
#                        ▼
#               ┌─────────────────┐
#               │      GOLD       │
#               │   vendas_gold   │
#               └────────┬────────┘
#                        │
#                        ▼
#                   Power BI
# ```
#
# | Tecnologia | Uso |
# |---|---|
# | PostgreSQL | Banco de dados |
# | SQLAlchemy Core | Conexão e SQL |
# | `text()` | SQL explícito |
# | Pandas | DataFrames e transformações |
# | `read_sql()` | PostgreSQL → Pandas |
# | `to_sql()` | Pandas → PostgreSQL |

# %% [markdown]
# # 📝 Exercícios
#
# ### Exercício 1 — Bronze
# Altere a consulta Bronze para trazer também o `status` do pedido.
#
# ### Exercício 2 — Silver
# Crie uma coluna `ticket_medio_item`:
#
# ```text
# valor_liquido / quantidade
# ```
#
# ### Exercício 3 — Silver
# Mantenha somente registros com `quantidade > 1`.
#
# ### Exercício 4 — Gold
# Crie uma Gold com:
#
# ```text
# id_cliente
# faturamento
# ```
#
# ### Exercício 5 — Gold
# Crie uma Gold com:
#
# ```text
# id_produto
# quantidade_vendida
# faturamento
# ```
#
# e mantenha somente produtos com faturamento maior que 1.000.
#
# ### Desafio final 🚀
# Crie uma Gold de **faturamento mensal**:
#
# ```text
# mes
# faturamento
# ```
#
# Dica:
#
# ```sql
# DATE_TRUNC('month', data_pedido)
# ```
